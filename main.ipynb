# %%
import pandas as pd

# %%
matches=pd.read_csv("matches.csv",index_col=0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 1  2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L  0.0  1.0
# 2  2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W  5.0  0.0
# 3  2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W  5.0  0.0
# 4  2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W  1.0  0.0
# 6  2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D  0.0  0.0
#
#          opponent  ...  match report  notes    sh   sot  dist   fk   pk pkatt  \
# 1       Tottenham  ...  Match Report    NaN  18.0   4.0  16.9  1.0  0.0   0.0
# 2    Norwich City  ...  Match Report    NaN  16.0   4.0  17.3  1.0  0.0   0.0
# 3         Arsenal  ...  Match Report    NaN  25.0  10.0  14.3  0.0  0.0   0.0
# 4  Leicester City  ...  Match Report    NaN  25.0   8.0  14.0  0.0  0.0   0.0
# 6     Southampton  ...  Match Report    NaN  16.0   1.0  15.7  1.0  0.0   0.0
#
#    season             team
# 1    2022  Manchester City
# 2    2022  Manchester City
# 3    2022  Manchester City
# 4    2022  Manchester City
# 6    2022  Manchester City
#
# [5 rows x 27 columns]

# %%
matches.shape
# Out:
# (1389, 27)

# %%
matches.isnull().sum()
# Out:
# date               0
# time               0
# comp               0
# round              0
# day                0
# venue              0
# result             0
# gf                 0
# ga                 0
# opponent           0
# xg                 0
# xga                0
# poss               0
# attendance       696
# captain            0
# formation          0
# referee            0
# match report       0
# notes           1389
# sh                 0
# sot                0
# dist               1
# fk                 0
# pk                 0
# pkatt              0
# season             0
# team               0
# dtype: int64

# %%
matches["team"].value_counts()
# Out:
# Southampton                 72
# Brighton and Hove Albion    72
# Manchester United           72
# West Ham United             72
# Newcastle United            72
# Burnley                     71
# Leeds United                71
# Crystal Palace              71
# Manchester City             71
# Wolverhampton Wanderers     71
# Tottenham Hotspur           71
# Arsenal                     71
# Leicester City              70
# Chelsea                     70
# Aston Villa                 70
# Everton                     70
# Liverpool                   38
# Fulham                      38
# West Bromwich Albion        38
# Sheffield United            38
# Brentford                   34
# Watford                     33
# Norwich City                33
# Name: team, dtype: int64

# %%
matches["round"].value_counts()
# Out:
# Matchweek 1     39
# Matchweek 16    39
# Matchweek 34    39
# Matchweek 32    39
# Matchweek 31    39
# Matchweek 29    39
# Matchweek 28    39
# Matchweek 26    39
# Matchweek 25    39
# Matchweek 24    39
# Matchweek 23    39
# Matchweek 2     39
# Matchweek 19    39
# Matchweek 17    39
# Matchweek 20    39
# Matchweek 15    39
# Matchweek 5     39
# Matchweek 3     39
# Matchweek 13    39
# Matchweek 12    39
# Matchweek 4     39
# Matchweek 11    39
# Matchweek 10    39
# Matchweek 9     39
# Matchweek 8     39
# Matchweek 14    39
# Matchweek 7     39
# Matchweek 6     39
# Matchweek 30    37
# Matchweek 27    37
# Matchweek 22    37
# Matchweek 21    37
# Matchweek 18    37
# Matchweek 33    32
# Matchweek 35    20
# Matchweek 36    20
# Matchweek 37    20
# Matchweek 38    20
# Name: round, dtype: int64

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %%
matches["date"]=pd.to_datetime(matches["date"])

# %%
matches
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L  0.0
# 39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L  0.0
# 40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W  1.0
# 41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0.0
# 42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  1.0
#
#      ga        opponent  ...  match report  notes    sh   sot  dist   fk   pk  \
# 1   1.0       Tottenham  ...  Match Report    NaN  18.0   4.0  16.9  1.0  0.0
# 2   0.0    Norwich City  ...  Match Report    NaN  16.0   4.0  17.3  1.0  0.0
# 3   0.0         Arsenal  ...  Match Report    NaN  25.0  10.0  14.3  0.0  0.0
# 4   0.0  Leicester City  ...  Match Report    NaN  25.0   8.0  14.0  0.0  0.0
# 6   0.0     Southampton  ...  Match Report    NaN  16.0   1.0  15.7  1.0  0.0
# ..  ...             ...  ...           ...    ...   ...   ...   ...  ...  ...
# 38  4.0       Tottenham  ...  Match Report    NaN   8.0   1.0  17.4  0.0  0.0
# 39  2.0  Crystal Palace  ...  Match Report    NaN   7.0   0.0  11.4  1.0  0.0
# 40  0.0         Everton  ...  Match Report    NaN  10.0   3.0  17.0  0.0  0.0
# 41  1.0   Newcastle Utd  ...  Match Report    NaN  11.0   1.0  16.0  1.0  0.0
# 42  0.0         Burnley  ...  Match Report    NaN  12.0   3.0  17.0  0.0  0.0
#
#    pkatt  season              team
# 1    0.0    2022   Manchester City
# 2    0.0    2022   Manchester City
# 3    0.0    2022   Manchester City
# 4    0.0    2022   Manchester City
# 6    0.0    2022   Manchester City
# ..   ...     ...               ...
# 38   0.0    2021  Sheffield United
# 39   0.0    2021  Sheffield United
# 40   0.0    2021  Sheffield United
# 41   0.0    2021  Sheffield United
# 42   0.0    2021  Sheffield United
#
# [1389 rows x 27 columns]

# %%
matches.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                     float64
# ga                     float64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                  float64
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                     float64
# pkatt                  float64
# season                   int64
# team                    object
# dtype: object

# %%
matches["venue_code"]=matches["venue"].astype("category").cat.codes

# %% [markdown]
# 0 - Away 1 - Home

# %%
matches["team_code"]=matches["team"].astype("category").cat.codes
matches["opp_code"]=matches["opponent"].astype("category").cat.codes

# %%
matches[["team","team_code"]].drop_duplicates()
# matches[["opponent","opp_code"]].drop_duplicates()
# matches["team"].unique()
# Out:
#                        team  team_code
# 1           Manchester City         12
# 1                   Chelsea          5
# 0                   Arsenal          0
# 0         Tottenham Hotspur         18
# 0         Manchester United         13
# 0           West Ham United         21
# 0   Wolverhampton Wanderers         22
# 0          Newcastle United         14
# 1            Leicester City         10
# 0  Brighton and Hove Albion          3
# 0                 Brentford          2
# 0               Southampton         17
# 0            Crystal Palace          6
# 0               Aston Villa          1
# 0              Leeds United          9
# 0                   Burnley          4
# 0                   Everton          7
# 0                   Watford         19
# 0              Norwich City         15
# 1                 Liverpool         11
# 0                    Fulham          8
# 0      West Bromwich Albion         20
# 0          Sheffield United         16

# %%
matches["hour"]=matches["time"].str.replace(":.+","",regex=True).astype("int")

# %%
matches["day_code"]=matches["day"].astype("category").cat.codes

# %% [markdown]
# 0 - Thu
# 1 - Fri
# 2 - Sat
# 3 - Sun
# 4 - Mon
# 5 - Tue
# 6 - Wed

# %%
matches["target"]=(matches["result"]=='W').astype("int")

# %% [markdown]
# 0 - Draw/Lose

# %% [markdown]
# 1 - Win

# %%
matches["hour"].unique()
# Out:
# array([16, 15, 12, 17, 14, 20, 19, 18, 13])

# %%
team=matches.loc[matches.team=="Manchester City"]
cor=team.corr().round(2)
cor
# Out:
# C:\Users\gaura\AppData\Local\Temp\ipykernel_20592\1515142853.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor=team.corr().round(2)
#               gf    ga    xg   xga  poss  attendance  notes    sh   sot  dist  \
# gf          1.00  0.00  0.53  0.00  0.16        0.04    NaN  0.22  0.57 -0.28
# ga          0.00  1.00 -0.20  0.74 -0.10        0.02    NaN  0.00 -0.12  0.22
# xg          0.53 -0.20  1.00 -0.17  0.12       -0.03    NaN  0.53  0.56 -0.58
# xga         0.00  0.74 -0.17  1.00 -0.22       -0.08    NaN -0.12 -0.17  0.24
# poss        0.16 -0.10  0.12 -0.22  1.00        0.10    NaN  0.36  0.26  0.02
# attendance  0.04  0.02 -0.03 -0.08  0.10        1.00    NaN -0.04 -0.22  0.15
# notes        NaN   NaN   NaN   NaN   NaN         NaN    NaN   NaN   NaN   NaN
# sh          0.22  0.00  0.53 -0.12  0.36       -0.04    NaN  1.00  0.57 -0.22
# sot         0.57 -0.12  0.56 -0.17  0.26       -0.22    NaN  0.57  1.00 -0.30
# dist       -0.28  0.22 -0.58  0.24  0.02        0.15    NaN -0.22 -0.30  1.00
# fk          0.07  0.21 -0.20  0.08 -0.10        0.18    NaN  0.10  0.07  0.32
# pk          0.20  0.10  0.33  0.16  0.13        0.28    NaN -0.02 -0.03  0.02
# pkatt       0.17  0.10  0.42  0.16 -0.03        0.20    NaN -0.13 -0.09 -0.02
# season      0.07 -0.10  0.19 -0.12  0.22        0.56    NaN  0.24  0.12 -0.17
# venue_code  0.18  0.09  0.12 -0.05  0.20        0.43    NaN  0.16  0.14  0.02
# team_code    NaN   NaN   NaN   NaN   NaN         NaN    NaN   NaN   NaN   NaN
# opp_code    0.03  0.16  0.01  0.08  0.15        0.22    NaN  0.10  0.13 -0.04
# hour        0.16  0.08 -0.05  0.06  0.04       -0.46    NaN -0.06  0.14  0.06
# day_code    0.16 -0.02 -0.01 -0.11  0.04       -0.10    NaN  0.05  0.17  0.04
# target      0.52 -0.53  0.35 -0.35  0.21        0.03    NaN -0.01  0.43 -0.27
#
#               fk    pk  pkatt  season  venue_code  team_code  opp_code  hour  \
# gf          0.07  0.20   0.17    0.07        0.18        NaN      0.03  0.16
# ga          0.21  0.10   0.10   -0.10        0.09        NaN      0.16  0.08
# xg         -0.20  0.33   0.42    0.19        0.12        NaN      0.01 -0.05
# xga         0.08  0.16   0.16   -0.12       -0.05        NaN      0.08  0.06
# poss       -0.10  0.13  -0.03    0.22        0.20        NaN      0.15  0.04
# attendance  0.18  0.28   0.20    0.56        0.43        NaN      0.22 -0.46
# notes        NaN   NaN    NaN     NaN         NaN        NaN       NaN   NaN
# sh          0.10 -0.02  -0.13    0.24        0.16        NaN      0.10 -0.06
# sot         0.07 -0.03  -0.09    0.12        0.14        NaN      0.13  0.14
# dist        0.32  0.02  -0.02   -0.17        0.02        NaN     -0.04  0.06
# fk          1.00 -0.09  -0.20   -0.12       -0.05        NaN      0.06  0.11
# pk         -0.09  1.00   0.83    0.10        0.20        NaN      0.07 -0.01
# pkatt      -0.20  0.83   1.00    0.01        0.21        NaN      0.03  0.01
# season     -0.12  0.10   0.01    1.00        0.02        NaN     -0.07 -0.22
# venue_code -0.05  0.20   0.21    0.02        1.00        NaN      0.06 -0.10
# team_code    NaN   NaN    NaN     NaN         NaN        NaN       NaN   NaN
# opp_code    0.06  0.07   0.03   -0.07        0.06        NaN      1.00 -0.09
# hour        0.11 -0.01   0.01   -0.22       -0.10        NaN     -0.09  1.00
# day_code    0.03 -0.05  -0.02   -0.10        0.09        NaN     -0.28  0.50
# target     -0.19  0.17   0.11    0.05       -0.02        NaN     -0.19 -0.01
#
#             day_code  target
# gf              0.16    0.52
# ga             -0.02   -0.53
# xg             -0.01    0.35
# xga            -0.11   -0.35
# poss            0.04    0.21
# attendance     -0.10    0.03
# notes            NaN     NaN
# sh              0.05   -0.01
# sot             0.17    0.43
# dist            0.04   -0.27
# fk              0.03   -0.19
# pk             -0.05    0.17
# pkatt          -0.02    0.11
# season         -0.10    0.05
# venue_code      0.09   -0.02
# team_code        NaN     NaN
# opp_code       -0.28   -0.19
# hour            0.50   -0.01
# day_code        1.00    0.15
# target          0.15    1.00

# %%
import matplotlib.pyplot as pyt
import seaborn as sns
pyt.figure(figsize=(25,20))
plot=sns.heatmap(matches.corr(),annot=True, fmt=".2f")
# Out:
# C:\Users\gaura\AppData\Local\Temp\ipykernel_20592\723704170.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plot=sns.heatmap(matches.corr(),annot=True, fmt=".2f")

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression(random_state=16)

# %%
train=matches[matches["date"]<'2022-1-1']
test=matches[matches["date"]>'2022-1-1']

# %%
predictors=["venue_code","team_code","opp_code","hour","day_code","xg","xga","gf"]

# %%
x=model.fit(train[predictors].values,train["target"])

# %%
preds=model.predict(test[predictors].values)

# %%
from sklearn.metrics import accuracy_score,precision_score
accuracy_score(test["target"],preds)
# Out:
# 0.8478260869565217

# %%
precision_score(test["target"],preds)
# Out:
# 0.8297872340425532

# %%
import pickle
file="Final.pkl"
pickle.dump(model,open(file,'wb'))

# %%
load=pickle.load(open(file,'rb'))

# %%
import numpy as np
arr=np.array([0,18,16,3,1.9,1.3,0,1.5])
result=load.predict(arr.reshape(1,-1))

# %%
if result[0]==1:
    print("Win")
else:
    print("Lose/Draw")
# Out:
# Win
